# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report ,accuracy_score

# %%
df = pd.read_csv('/content/Iris (1).csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
x = df[df.columns[:-1]]
y = df[df.columns[-1]]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=16)

# %%
model1 = GaussianNB()

# %%
#train
model1.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred =  model1.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.92      1.00      0.96        12
#  Iris-virginica       1.00      0.88      0.93         8
#
#        accuracy                           0.97        30
#       macro avg       0.97      0.96      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
#-----------------------------------------------------------------------------------------
s = []
for i in range(0,101):
  x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=i)
  model1 = GaussianNB()
  model1.fit(x_train,y_train)
  y_pred = model1.predict(x_test)
  print(f'For random_state : {i}, the accuracy in : {accuracy_score(y_test,y_pred)}')
  s.append(accuracy_score(y_test,y_pred))
# Out:
# For random_state : 0, the accuracy in : 1.0
# For random_state : 1, the accuracy in : 1.0
# For random_state : 2, the accuracy in : 1.0
# For random_state : 3, the accuracy in : 1.0
# For random_state : 4, the accuracy in : 1.0
# For random_state : 5, the accuracy in : 1.0
# For random_state : 6, the accuracy in : 1.0
# For random_state : 7, the accuracy in : 0.9666666666666667
# For random_state : 8, the accuracy in : 0.9666666666666667
# For random_state : 9, the accuracy in : 1.0
# For random_state : 10, the accuracy in : 1.0
# For random_state : 11, the accuracy in : 1.0
# For random_state : 12, the accuracy in : 1.0
# For random_state : 13, the accuracy in : 1.0
# For random_state : 14, the accuracy in : 0.9666666666666667
# For random_state : 15, the accuracy in : 1.0
# For random_state : 16, the accuracy in : 0.9666666666666667
# For random_state : 17, the accuracy in : 1.0
# For random_state : 18, the accuracy in : 1.0
# For random_state : 19, the accuracy in : 1.0
# For random_state : 20, the accuracy in : 1.0
# For random_state : 21, the accuracy in : 1.0
# For random_state : 22, the accuracy in : 1.0
# For random_state : 23, the accuracy in : 1.0
# For random_state : 24, the accuracy in : 1.0
# For random_state : 25, the accuracy in : 1.0
# For random_state : 26, the accuracy in : 0.9666666666666667
# For random_state : 27, the accuracy in : 0.9666666666666667
# For random_state : 28, the accuracy in : 1.0
# For random_state : 29, the accuracy in : 0.9666666666666667
# For random_state : 30, the accuracy in : 1.0
# For random_state : 31, the accuracy in : 1.0
# For random_state : 32, the accuracy in : 1.0
# For random_state : 33, the accuracy in : 1.0
# For random_state : 34, the accuracy in : 1.0
# For random_state : 35, the accuracy in : 1.0
# For random_state : 36, the accuracy in : 1.0
# For random_state : 37, the accuracy in : 1.0
# For random_state : 38, the accuracy in : 1.0
# For random_state : 39, the accuracy in : 0.9666666666666667
# For random_state : 40, the accuracy in : 1.0
# For random_state : 41, the accuracy in : 1.0
# For random_state : 42, the accuracy in : 1.0
# For random_state : 43, the accuracy in : 1.0
# For random_state : 44, the accuracy in : 0.9666666666666667
# For random_state : 45, the accuracy in : 1.0
# For random_state : 46, the accuracy in : 0.9666666666666667
# For random_state : 47, the accuracy in : 1.0
# For random_state : 48, the accuracy in : 1.0
# For random_state : 49, the accuracy in : 0.9666666666666667
# For random_state : 50, the accuracy in : 1.0
# For random_state : 51, the accuracy in : 1.0
# For random_state : 52, the accuracy in : 1.0
# For random_state : 53, the accuracy in : 1.0
# For random_state : 54, the accuracy in : 1.0
# For random_state : 55, the accuracy in : 1.0
# For random_state : 56, the accuracy in : 1.0
# For random_state : 57, the accuracy in : 1.0
# For random_state : 58, the accuracy in : 1.0
# For random_state : 59, the accuracy in : 1.0
# For random_state : 60, the accuracy in : 0.9666666666666667
# For random_state : 61, the accuracy in : 0.9666666666666667
# For random_state : 62, the accuracy in : 1.0
# For random_state : 63, the accuracy in : 1.0
# For random_state : 64, the accuracy in : 1.0
# For random_state : 65, the accuracy in : 1.0
# For random_state : 66, the accuracy in : 1.0
# For random_state : 67, the accuracy in : 1.0
# For random_state : 68, the accuracy in : 1.0
# For random_state : 69, the accuracy in : 1.0
# For random_state : 70, the accuracy in : 1.0
# For random_state : 71, the accuracy in : 1.0
# For random_state : 72, the accuracy in : 1.0
# For random_state : 73, the accuracy in : 1.0
# For random_state : 74, the accuracy in : 1.0
# For random_state : 75, the accuracy in : 1.0
# For random_state : 76, the accuracy in : 1.0
# For random_state : 77, the accuracy in : 0.9333333333333333
# For random_state : 78, the accuracy in : 1.0
# For random_state : 79, the accuracy in : 1.0
# For random_state : 80, the accuracy in : 1.0
# For random_state : 81, the accuracy in : 1.0
# For random_state : 82, the accuracy in : 1.0
# For random_state : 83, the accuracy in : 0.9666666666666667
# For random_state : 84, the accuracy in : 1.0
# For random_state : 85, the accuracy in : 1.0
# For random_state : 86, the accuracy in : 1.0
# For random_state : 87, the accuracy in : 1.0
# For random_state : 88, the accuracy in : 1.0
# For random_state : 89, the accuracy in : 1.0
# For random_state : 90, the accuracy in : 1.0
# For random_state : 91, the accuracy in : 1.0
# For random_state : 92, the accuracy in : 0.9666666666666667
# For random_state : 93, the accuracy in : 1.0
# For random_state : 94, the accuracy in : 1.0
# For random_state : 95, the accuracy in : 1.0
# For random_state : 96, the accuracy in : 1.0
# For random_state : 97, the accuracy in : 1.0
# For random_state : 98, the accuracy in : 1.0
# For random_state : 99, the accuracy in : 0.9666666666666667
# For random_state : 100, the accuracy in : 1.0

# %%
#0.8246753246753247 ---- 16 wala
#0.8246753246753247
max(s)
# Out:
# 1.0

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
x = df[df.columns[:-1]]

# %%
x
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]
